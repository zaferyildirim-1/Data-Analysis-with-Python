# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <div style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;"></div>
#
# <p style="text-align: center;"> <a href="https://ondiande.com/"> <img src="https://i.ibb.co/mvHRT4S/ONDIA-logo.png" width="500" height="200" class="img-fluid" alt="ONDIA LOGO" title="INTELLIGENT & PERSONALIZED SOLUTIONS TO DATA ANALYSIS AND DATA MANAGEMENT ISSUES"> </a> </p>
#
# <div style="background-color:#58B8E4; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;">
#   Intelligent & Personalized Solutions
# </div>

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:300%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ![Image_Assignment](https://i.ibb.co/cY9HhF7/bnote-assignment.gif)
#
# <div style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;"></div>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Assignment 02 (Pandas)</p>
#
# <div style="background-color:#58B8E4; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;"></div>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTENT</p>
#
#
# * [CONTEXT](#0)
# * [ABOUT THE DATASET & ATRIBUTES](#00)
# * [INSTRUCTIONS (Tasks in the Assignment)](#000)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#1)
# * [Task 01. Checking the head of the DataFrame](#2)
# * [Task 02. How many rows and columns are there?](#3)
# * [Task 03. What is the average Purchase Price?](#4)
# * [Task 04. What were the highest and lowest purchase prices?](#5)
# * [Task 05. Listing the country names and number of records belongs to each country](#6)
# * [Task 06. How many records are as Country United Kingdom?](#7)
# * [Task 07. Creating a column named Total which shows the total amount of spend using UnitPrice and Quantity](#8)
# * [Task 08. Showing total spending amount according to the Countries](#9)
# * [Task 09. Which Country spend least?](#10)
# * [Task 10. Calculating average of spending according to country with apply function](#11)
# * [Task 11. Calculating average, mean, max of spending according to country with agg function](#12)
# * [Task 12. What is the max Total spending in whole dataset and show the records of that spending?](#13)
# * [Task 13. How many people who live in Spain spend more than average Total?](#14)
# * [Task 14. Converting datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2](#15)
# * [Task 15. Taking only date values (year-month-day) from InvoiceDate2 and assign it to a new column named "date"](#16)
# * [Task 16. Dropping InvoiceDate2 and InvoiceDate columns permanently](#17)
# * [Task 17. Removing A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method](#18)
# * [Task 18. Taking only Total and date columns with loc and craete a new df named ecom2](#19)
# * [Task 19. Taking only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3](#20)
# * [Task 20. Combining ecom2 and ecom3 with concat() method](#21)
# * [Task 21. Combining the common (intersected) values of ecom2 and ecom3 with merge() method](#22)
# * [Task 22. Combining ecom2 and ecom3 with join() method](#23)
# * [THE END OF THE ASSIGNMENT 02](#24)

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTEXT</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# E-Commerce is currently one of the fastest and dynamically evolving industries in the world. Its popularity has been growing rapidly with the ease of digital transactions and quick door-to-door deliveries. A major source of big tech companies revenues comes from the interaction of their underlying proprietary algorithms that are heavily powered by data science, so it’s fundamental to understand the methods applied to maintain and grow the number of clients.
#
# "This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers."

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE DATASET & ATRIBUTES</p>
#
# <a id="00"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Typically e-commerce datasets are proprietary and consequently hard to find among publicly available data. However, The [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) has made this dataset containing actual transactions from 2010 and 2011. The dataset is maintained on their site, where it can be found by the title "Online Retail".
#
# **Attribute Information:**
#
# **``InvoiceNo:``** Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.<br>
# **``StockCode:``** Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.<br>
# **``Description:``** Product (item) name. Nominal.<br>
# **``Quantity:``** The quantities of each product (item) per transaction. Numeric.<br>
# **``InvoiceDate:``** Invice Date and time. Numeric, the day and time when each transaction was generated.<br>
# **``UnitPrice:``** Unit price. Numeric, Product price per unit in sterling.<br>
# **``CustomerID:``** Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.<br>
# **``Country:``** Country name. Nominal, the name of the country where each customer resides.<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">INSTRUCTIONS (Tasks in the Assignment)</p>
#
# <a id="000"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **In this assignment you're required to handle with the following tasks:**
#
# - **Task 01.** Checking the head of the DataFrame.<br>
# - **Task 02.** How many rows and columns are there?<br>
# - **Task 03.** What is the average of Product sold and the average price of Product per unit?<br>
# - **Task 04.** What were the highest and lowest purchase prices?<br>
# - **Task 05.** Listing the country names and number of their records belongs to each country.<br>
# - **Task 06.** How many records are as Country United Kingdom?<br>
# - **Task 07.** Creating a column named "Total" which shows the total amount of spend using UnitPrice and Quantity.<br>
# - **Task 08.** Showing total spending amount according to the Countries and their percentages.<br>
# - **Task 09.** Which Country spend least?<br>
# - **Task 10.** Calculating average of spending according to country with apply function  and create a new feature named "Average_Spend".<br>
# - **Task 11.** Calculating average, min, max of spending according to country with agg function and create new features named "Max_Spend" and "Min_Spend".<br>
# - **Task 12.** What is the max Total spending in whole dataset and show all records of that spending?<br>
# - **Task 13.** How many people who live in Spain spend more than average Total?<br>
# - **Task 14.** Converting datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2.<br>
# - **Task 15.** Taking only date values (year-month-day) from InvoiceDate2 and assign it to a new column named "date".<br>
# - **Task 16.** Dropping InvoiceDate2 and InvoiceDate columns permanently.<br>
# - **Task 17.** Removing A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method.<br>
# - **Task 18.** Taking only Total and date columns with loc and craete a new df named ecom2.<br>
# - **Task 19.** Taking only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3.<br>
# - **Task 20.** Combining ecom2 and ecom3 with concat() method.<br>
# - **Task 21.** Combining the common (intersected) values of ecom2 and ecom3 with merge() method.<br>
# - **Task 22.** Combining ecom2 and ecom3 with join() method.<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS STUDY</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy and Pandas you can import them as a library. Then read the dataset and assig it as **``"ecom"``**:

# %%
import numpy as np
import pandas as pd

# %%
ecom = pd.read_csv("data.csv", encoding="windows-1252")
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 01: Check the Head of the DataFrame</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LdKJHb6/assignment1a.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 02: How many rows and columns are there?</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# YOUR CODE IS HERE 
ecom.shape
# Out:
# (541909, 8)

# %% [raw]
# Desired Output:
#
# (541909, 8)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 03: What is the average of Product sold and the average price of Product per unit?</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom.sample(3)
ecom.UnitPrice.mean()
# Out:
# 4.611113626088513

# %% [raw]
# Desired Output:
#
# 4.611113626083471

# %%
# YOUR CODE IS HERE 
ecom.Quantity.mean()
# Out:
# 9.55224954743324

# %% [raw]
# Desired Output:
#
# 9.55224954743324

# %%
# YOUR CODE IS HERE 

ecom[['UnitPrice', 'Quantity']].mean()
# Out:
# UnitPrice    4.611114
# Quantity     9.552250
# dtype: float64

# %% [raw]
# Desired Output:
#
# UnitPrice    4.611114
# Quantity     9.552250
# dtype: float64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 04: What are the highest and lowest purchase prices?</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom.sample()
ecom.UnitPrice.max()
# Out:
# 38970.0

# %% [raw]
# Desired Output:
#
# 38970.0

# %%
# YOUR CODE IS HERE 

ecom.UnitPrice.min()
# Out:
# -11062.06

# %% [raw]
# Desired Output:
#
# -11062.06

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 05: List the country names and number of their records belongs to each country</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

ecom['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 06: How many records are there in the United Kingdom?</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

ecom[ecom['Country'] == 'United Kingdom'].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [raw]
# Desired Output:
#
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 07: Create a column named "Total" which shows the total amount of spend using UnitPrice and Quantity</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
#ecom.sample(3)
ecom['Total'] = ecom['UnitPrice']	* ecom['Quantity']	
ecom['Total']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [raw]
# Desired Output:
#
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %%
# YOUR CODE IS HERE 
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7y5d0sp/assignment2b.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 08: Show total spending amount according to the Countries and their percentages.</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom.groupby("Country")['Total'].sum()
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# Portugal                  29367.020
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     54774.580
# Sweden                    36595.910
# Switzerland               56385.350
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          8187806.364
# Unspecified                4749.790
# Name: Total, dtype: float64

# %% [raw]
# Desired Output:
#
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# Portugal                  29367.020
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     54774.580
# Sweden                    36595.910
# Switzerland               56385.350
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          8187806.364
# Unspecified                4749.790
# Name: Total, dtype: float64

# %%
# YOUR CODE IS HERE 


ecom.groupby("Country")['Total'].sum() / ecom.groupby("Country")['Total'].sum().sum() * 100
# Out:
# Country
# Australia                1.406246
# Austria                  0.104171
# Bahrain                  0.005626
# Belgium                  0.419697
# Brazil                   0.011732
# Canada                   0.037613
# Channel Islands          0.206061
# Cyprus                   0.132813
# Czech Republic           0.007260
# Denmark                  0.192538
# EIRE                     2.700899
# European Community       0.013252
# Finland                  0.229045
# France                   2.025123
# Germany                  2.274353
# Greece                   0.048324
# Hong Kong                0.103788
# Iceland                  0.044215
# Israel                   0.081125
# Italy                    0.173276
# Japan                    0.362552
# Lebanon                  0.017377
# Lithuania                0.017040
# Malta                    0.025703
# Netherlands              2.920280
# Norway                   0.360734
# Poland                   0.073998
# Portugal                 0.301270
# RSA                      0.010282
# Saudi Arabia             0.001346
# Singapore                0.093564
# Spain                    0.561920
# Sweden                   0.375429
# Switzerland              0.578445
# USA                      0.017757
# United Arab Emirates     0.019515
# United Kingdom          83.996903
# Unspecified              0.048727
# Name: Total, dtype: float64

# %% [raw]
# Desired Output:
#
# Country
# United Kingdom          83.996903
# Netherlands              2.920280
# EIRE                     2.700899
# Germany                  2.274353
# France                   2.025123
# Australia                1.406246
# Switzerland              0.578445
# Spain                    0.561920
# Belgium                  0.419697
# Sweden                   0.375429
# Japan                    0.362552
# Norway                   0.360734
# Portugal                 0.301270
# Finland                  0.229045
# Channel Islands          0.206061
# Denmark                  0.192538
# Italy                    0.173276
# Cyprus                   0.132813
# Austria                  0.104171
# Hong Kong                0.103788
# Singapore                0.093564
# Israel                   0.081125
# Poland                   0.073998
# Unspecified              0.048727
# Greece                   0.048324
# Iceland                  0.044215
# Canada                   0.037613
# Malta                    0.025703
# United Arab Emirates     0.019515
# USA                      0.017757
# Lebanon                  0.017377
# Lithuania                0.017040
# European Community       0.013252
# Brazil                   0.011732
# RSA                      0.010282
# Czech Republic           0.007260
# Bahrain                  0.005626
# Saudi Arabia             0.001346
# Name: Total, dtype: float64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 09: Which Country spend least?</p>
#
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 


ecom.groupby("Country")['Total'].sum().min()
# Out:
# 131.17

# %% [raw]
# Desired Output:
#
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 10: Calculate the average of spending according to country with apply function and create a new feature named "Average_Spend"</p>
#
# <a id="11"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
#ecom.sample(5)

ecom.groupby("Country")["Total"].apply(np.mean)
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [raw]
# Desired Output:
#
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %%
# YOUR CODE IS HERE 

ecom["Average_Spend"] = ecom.groupby("Country")["Total"].transform("mean")

ecom.sample(2)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 407940    571917     22678    FRENCH BLUE METAL DOOR SIGN 3        10
# 522837    580469     22346  PARTY PIZZA DISH GREEN POLKADOT         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 407940  10/19/2011 15:46       1.25     13078.0  United Kingdom  12.50
# 522837   12/4/2011 12:32       0.19     14583.0  United Kingdom   1.14
#
#         Average_Spend  Max_Spend  Min_Spend        InvoiceDate2  \
# 407940      16.525065   168469.6  -168469.6 2011-10-19 15:46:00
# 522837      16.525065   168469.6  -168469.6 2011-12-04 12:32:00
#
#                       date
# 407940 2011-10-19 15:46:00
# 522837 2011-12-04 12:32:00

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/b3m1jhs/assignment2c.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 11: Calculate average, min, max of spending according to country with agg() function and create new features named "Max_Spend" and "Min_Spend"</p>
#
# <a id="12"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom.groupby('Country').agg({'Total':("min", 'max', "mean")})
# Out:
#                           Total
#                             min        max        mean
# Country
# Australia               -425.00    1718.40  108.877895
# Austria                  -21.25     360.00   25.322494
# Bahrain                 -205.74     205.74   28.863158
# Belgium                  -19.95     165.00   19.773301
# Brazil                    15.00     175.20   35.737500
# Canada                     2.50     550.94   24.280662
# Channel Islands         -293.00     408.00   26.499063
# Cyprus                  -320.69     320.69   20.813971
# Czech Republic           -35.76      70.80   23.590667
# Denmark                  -59.80     428.40   48.247147
# EIRE                   -1917.00    2365.20   32.122599
# European Community        -8.50      60.00   21.176230
# Finland                  -80.00     551.20   32.124806
# France                 -8322.12    4161.06   23.069288
# Germany                 -599.50     876.00   23.348943
# Greece                   -50.00     175.20   32.263836
# Hong Kong              -2653.95    2653.95   35.128611
# Iceland                    5.04     249.60   23.681319
# Israel                  -136.00     350.40   26.625657
# Italy                    -89.55     300.00   21.034259
# Japan                  -1591.20    3794.40   98.716816
# Lebanon                   10.20     153.00   37.641778
# Lithuania                 13.20     122.40   47.458857
# Malta                   -130.00     455.00   19.728110
# Netherlands             -266.40    4992.00  120.059696
# Norway                  -376.50     700.00   32.378877
# Poland                   -39.80     120.00   21.152903
# Portugal               -1241.98    1241.98   19.333127
# RSA                        0.00      38.25   17.281207
# Saudi Arabia             -14.75      19.80   13.117000
# Singapore              -3949.32    3949.32   39.827031
# Spain                  -1715.85    1350.00   21.624390
# Sweden                 -1188.00    1188.00   79.211926
# Switzerland             -179.00     360.00   28.164510
# USA                      -74.88      81.36    5.948179
# United Arab Emirates       3.48     153.00   27.974706
# United Kingdom       -168469.60  168469.60   16.525065
# Unspecified                0.19      69.36   10.649753

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0qRCRjH/assignment2d.png)

# %%
# YOUR CODE IS HERE 

ecom["Max_Spend"] = ecom["Country"].map(ecom.groupby("Country")["Total"].max())
ecom["Min_Spend"] = ecom["Country"].map(ecom.groupby("Country")["Total"].min())
# ecom.drop(columns=["min_spend"], inplace=True)

ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...                 ...        ...         ...             ...    ...
# 541904  12/9/2011 12:50       0.85     12680.0          France  10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France  12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France  14.85
#
#         Average_Spend  Max_Spend  Min_Spend
# 0           16.525065  168469.60 -168469.60
# 1           16.525065  168469.60 -168469.60
# 2           16.525065  168469.60 -168469.60
# 3           16.525065  168469.60 -168469.60
# 4           16.525065  168469.60 -168469.60
# ...               ...        ...        ...
# 541904      23.069288    4161.06   -8322.12
# 541905      23.069288    4161.06   -8322.12
# 541906      23.069288    4161.06   -8322.12
# 541907      23.069288    4161.06   -8322.12
# 541908      23.069288    4161.06   -8322.12
#
# [541909 rows x 12 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Smd3Tkt/assignment2e.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 12: What is the max Total spending in whole dataset and show all records of that spending?</p>
#
# <a id="13"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

max_total_spending = ecom["Total"].max()

ecom[ecom["Total"] == max_total_spending]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total  \
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6
#
#         Average_Spend  Max_Spend  Min_Spend
# 540421      16.525065   168469.6  -168469.6

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2W9t4nh/assignment2f.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 13: How many people who live in Spain spend more than average Total?</p>
#
# <a id="14"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
#ecom                      .count()
#average_total_spending = ecom["Total"].mean()
ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())].count()
# Out:
# InvoiceNo        728
# StockCode        728
# Description      728
# Quantity         728
# InvoiceDate      728
# UnitPrice        728
# CustomerID       728
# Country          728
# Total            728
# Average_Spend    728
# Max_Spend        728
# Min_Spend        728
# dtype: int64

# %% [raw]
# Desired Output:
#
# InvoiceNo        728
# StockCode        728
# Description      728
# Quantity         728
# InvoiceDate      728
# UnitPrice        728
# CustomerID       728
# Country          728
# Total            728
# Average_Spend    728
# dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 14: Convert datatype of "InvoiceDate" to datetime and assign it to new column name "InvoiceDate2"</p>
#
# <a id="15"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom["InvoiceDate2"] = pd.to_datetime(ecom["InvoiceDate"])
ecom["InvoiceDate2"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %% [raw]
# Desired Output:
#
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %%
# YOUR CODE IS HERE 
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      541909 non-null  object
#  1   StockCode      541909 non-null  object
#  2   Description    540455 non-null  object
#  3   Quantity       541909 non-null  int64
#  4   InvoiceDate    541909 non-null  object
#  5   UnitPrice      541909 non-null  float64
#  6   CustomerID     406829 non-null  float64
#  7   Country        541909 non-null  object
#  8   Total          541909 non-null  float64
#  9   Average_Spend  541909 non-null  float64
#  10  Max_Spend      541909 non-null  float64
#  11  Min_Spend      541909 non-null  float64
#  12  InvoiceDate2   541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(1), object(5)
# memory usage: 53.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      541909 non-null  object
#  1   StockCode      541909 non-null  object
#  2   Description    540455 non-null  object
#  3   Quantity       541909 non-null  int64
#  4   InvoiceDate    541909 non-null  object
#  5   UnitPrice      541909 non-null  float64
#  6   CustomerID     406829 non-null  float64
#  7   Country        541909 non-null  object
#  8   Total          541909 non-null  float64
#  9   Average_Spend  541909 non-null  float64
#  10  InvoiceDate2   541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 45.5+ MB

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 15: Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named **``date``**</p>
#
# <a id="16"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

a = ecom["InvoiceDate2"]
ecom["date"] = pd.to_datetime(a , format = "%d/%m/%Y")
ecom["date"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: date, Length: 541909, dtype: datetime64[ns]

# %% [raw]
# Desired Output:
#
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: date, Length: 541909, dtype: object

# %%
# YOUR CODE IS HERE 

ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...                 ...        ...         ...             ...    ...
# 541904  12/9/2011 12:50       0.85     12680.0          France  10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France  12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France  14.85
#
#         Average_Spend  Max_Spend  Min_Spend        InvoiceDate2  \
# 0           16.525065  168469.60 -168469.60 2010-12-01 08:26:00
# 1           16.525065  168469.60 -168469.60 2010-12-01 08:26:00
# 2           16.525065  168469.60 -168469.60 2010-12-01 08:26:00
# 3           16.525065  168469.60 -168469.60 2010-12-01 08:26:00
# 4           16.525065  168469.60 -168469.60 2010-12-01 08:26:00
# ...               ...        ...        ...                 ...
# 541904      23.069288    4161.06   -8322.12 2011-12-09 12:50:00
# 541905      23.069288    4161.06   -8322.12 2011-12-09 12:50:00
# 541906      23.069288    4161.06   -8322.12 2011-12-09 12:50:00
# 541907      23.069288    4161.06   -8322.12 2011-12-09 12:50:00
# 541908      23.069288    4161.06   -8322.12 2011-12-09 12:50:00
#
#                       date
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [541909 rows x 14 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/hdQm0jx/assignment2g.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 16: Drop "InvoiceDate2" and "InvoiceDate" columns permanently</p>
#
# <a id="17"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

ecom.drop(columns=["InvoiceDate2", "InvoiceDate"], inplace=True)
ecom.sample(3)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 383410    570019     22227  HANGING HEART MIRROR DECORATION          1
# 150932    549525     22427           ENAMEL FLOWER JUG CREAM         1
# 188027    553013    84912B                GREEN ROSE WASHBAG         1
#
#         UnitPrice  CustomerID         Country  Total  Average_Spend  \
# 383410       0.65     17841.0  United Kingdom   0.65      16.525065
# 150932      11.63         NaN  United Kingdom  11.63      16.525065
# 188027       3.29         NaN  United Kingdom   3.29      16.525065
#
#         Max_Spend  Min_Spend                date
# 383410   168469.6  -168469.6 2011-10-07 10:13:00
# 150932   168469.6  -168469.6 2011-04-08 15:44:00
# 188027   168469.6  -168469.6 2011-05-12 18:19:00

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2dPtL0k/assignment2h.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 17: Remove A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method</p>
#
# <a id="18"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
# ecom.head(5)
ecom.loc[:4, "StockCode"] = ecom.loc[:4, "StockCode"].str.replace(r"[ABGE]", "", regex=True)
ecom.loc[:4, "StockCode"]
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [raw]
# Desired Output:
#
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 18: Take only "Total" and "date" columns with loc and craete a new df named **``ecom2``**</p>
#
# <a id="19"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
#ecom.loc[:, ["Total", "date"]]
ecom2 = ecom.loc[:, ["Total", "date"]]
ecom2.head()
# Out:
#    Total                date
# 0  15.30 2010-12-01 08:26:00
# 1  20.34 2010-12-01 08:26:00
# 2  22.00 2010-12-01 08:26:00
# 3  20.34 2010-12-01 08:26:00
# 4  20.34 2010-12-01 08:26:00

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/yFyxdCz/assignment2j.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 19: Take only "InvoiceNo" and "CustomerID" columns with iloc and craete a new df named **``ecom32``**</p>
#
# <a id="20"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 
ecom32 = ecom.iloc[:, [0, 5, 7]]
ecom32
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9HsWScR/assignment2k.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 20: Combine "ecom2" and "ecom3" with concat() method</p>
#
# <a id="21"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

ecom_yeni = pd.concat([ecom2, ecom32])

ecom_yeni
# Out:
#         Total                date InvoiceNo  UnitPrice Country
# 0       15.30 2010-12-01 08:26:00       NaN        NaN     NaN
# 1       20.34 2010-12-01 08:26:00       NaN        NaN     NaN
# 2       22.00 2010-12-01 08:26:00       NaN        NaN     NaN
# 3       20.34 2010-12-01 08:26:00       NaN        NaN     NaN
# 4       20.34 2010-12-01 08:26:00       NaN        NaN     NaN
# ...       ...                 ...       ...        ...     ...
# 541904    NaN                 NaT    581587       0.85  France
# 541905    NaN                 NaT    581587       2.10  France
# 541906    NaN                 NaT    581587       4.15  France
# 541907    NaN                 NaT    581587       4.15  France
# 541908    NaN                 NaT    581587       4.95  France
#
# [1083818 rows x 5 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6NGsVMy/assignment2l.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 21: Combine the common (intersected) values of "ecom2" and "ecom3" with merge() method</p>
#
# <a id="22"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **If you "MemoryError" occurs, take only the first 100 rows from bot DFs**

# %%
# YOUR CODE IS HERE 
xxx = ecom2.iloc[:100, :]
yyy = ecom32.iloc[:100, :]

# Merge on common columns (intersection of values)
ecom_merged = xxx.merge(yyy, how="inner")
ecom_merged
# Out:
#      Total                date InvoiceNo  CustomerID
# 0     15.3 2010-12-01 08:26:00    536365     17850.0
# 1     15.3 2010-12-01 08:26:00    536373     17850.0
# 2     15.3 2010-12-01 08:26:00    536373     17850.0
# 3     15.3 2010-12-01 08:26:00    536375     17850.0
# 4     15.3 2010-12-01 08:26:00    536375     17850.0
# ..     ...                 ...       ...         ...
# 395   13.2 2010-12-01 09:37:00    536378     14688.0
# 396   13.2 2010-12-01 09:37:00    536378     14688.0
# 397   13.2 2010-12-01 09:37:00    536378     14688.0
# 398   13.2 2010-12-01 09:37:00    536378     14688.0
# 399   13.2 2010-12-01 09:37:00    536378     14688.0
#
# [400 rows x 4 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/3cgVkjv/assignment2m.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 22: Combine "ecom2" and "ecom3" with join() method</p>
#
# <a id="23"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# YOUR CODE IS HERE 

zzz = ecom2.iloc[:100, :]
ttt = ecom32.iloc[:100, :]

ecom_joined = zzz.join(ttt, how="inner", lsuffix="_zzz", rsuffix="ttt")
ecom_joined
# Out:
#     Total_zzz                date InvoiceNo  CustomerID  Totalttt
# 0       15.30 2010-12-01 08:26:00    536365     17850.0     15.30
# 1       20.34 2010-12-01 08:26:00    536365     17850.0     20.34
# 2       22.00 2010-12-01 08:26:00    536365     17850.0     22.00
# 3       20.34 2010-12-01 08:26:00    536365     17850.0     20.34
# 4       20.34 2010-12-01 08:26:00    536365     17850.0     20.34
# ..        ...                 ...       ...         ...       ...
# 95      15.30 2010-12-01 09:37:00    536378     14688.0     15.30
# 96      50.40 2010-12-01 09:37:00    536378     14688.0     50.40
# 97      13.20 2010-12-01 09:37:00    536378     14688.0     13.20
# 98      13.20 2010-12-01 09:37:00    536378     14688.0     13.20
# 99      13.20 2010-12-01 09:37:00    536378     14688.0     13.20
#
# [100 rows x 5 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DfS2KqQ/assignment2n.png)

# %% [markdown]
# <hr>
#
# <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#635EA7; font-size:350%; text-align:center; border-radius:10px 10px;">End of The Assignment - 2</p>
#
# # <span style="color:#DA55E5">**Now. it's time to relax!**<span>
#
# ![Image_Assignment](https://i.ibb.co/jZD3Mqb/relaxing.jpg)

# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>
